# %%
# %pip install pdfplumber openai python-pptx requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pilothub.ppt2hb import AIHandbookMaker

# %%
api_key = "your OpenAI key"

maker = AIHandbookMaker(
    ppt_path="Module_1.1_Introduction_to_IoT_and_IIOT.pptx",
    api_key=api_key
)

maker.generate_handbook("Enhanced_Trainer_Handbook.docx")
# Out:
# 📄 Converting PPT to PDF...
#
#
#
# ✅ Converted 100 pages to images in 'c:\Users\divya\OneDrive\Desktop\pilothub\slide_images'
#
# 📝 Generating introduction slide...
# ✅ Introduction slide content generated and added.
# 🔍 Identifying topics by analyzing page headings...
#    Page 1: Industrial IoT...
#    Page 2: 01...
#    Page 3: IoT & IIoT...
#    Page 4: Learning Objective...
#    Page 5: Internet...
#    Page 6: Internet: Network...
#    Page 7: Things: Physical Devices...
#    Page 8: What is Internet of Things?...
#    Page 9: How IoT Works...
#    Page 10: Cricket...
#    Page 11: Case Study: Future of Car Insurance with IoT...
#    Page 12: Industrial Internet...
#    Page 13: Industrial Network   +...
#    Page 14: Connected Machines in Industry...
#    Page 15: How Industry Connectivity Has Evolved...
#    Page 16: The Industrial IoT Process Flow...
#    Page 17: Key Differences between Consumer IoT and IIoT...
#    Page 18: How IIOT drive Industry4.0...
# ...

# %%
from pilothub.ppt2hb_student import AIHandbookMakerStudent

# %%
api_key = " your OpenAI key"

maker = AIHandbookMakerStudent(
    ppt_path="Module_1.1_Introduction_to_IoT_and_IIOT.pptx",
    api_key=api_key
)

maker.generate_handbook("Enhanced_Student_Handbook.docx")
# Out:
# 📄 Converting PPT to PDF...
# ✅ PDF created successfully using PowerPoint COM.
# ✅ Converted 100 pages to images in 'c:\Users\divya\OneDrive\Desktop\pilothub\slide_images'
#
# 📝 Generating introduction slide...
# ✅ Introduction slide content generated and added.
# 🔍 Identifying topics by analyzing page headings...
#    Page 1: Industrial IoT...
#    Page 2: 01...
#    Page 3: IoT & IIoT...
#    Page 4: Learning Objective...
#    Page 5: Internet...
#    Page 6: Internet: Network...
#    Page 7: Things: Physical Devices...
#    Page 8: What is Internet of Things?...
#    Page 9: How IoT Works...
#    Page 10: Cricket...
#    Page 11: Case Study: Future of Car Insurance with IoT...
#    Page 12: Industrial Internet...
#    Page 13: Industrial Network   +...
#    Page 14: Connected Machines in Industry...
#    Page 15: How Industry Connectivity Has Evolved...
#    Page 16: The Industrial IoT Process Flow...
#    Page 17: Key Differences between Consumer IoT and IIoT...
# ...
